# %% [markdown]
# # First prg.

# %% [markdown]
# ## Imprimir fib de 30, 50, 80

# %% [markdown]
# ### La formula que he usado es :

# %%
from IPython import display

# %%
display.Image("img.png")

# %%
def fib(n):
    if n<=1:
        return n
    else:
        return (fib(n-1)+fib(n-2))

# %%
fib(40)
# Out:
# 102334155
